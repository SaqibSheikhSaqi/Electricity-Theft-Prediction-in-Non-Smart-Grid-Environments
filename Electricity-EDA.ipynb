# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
## Display all the columns of the dataframe

pd.pandas.set_option('display.max_columns',None)

# %%
dataset=pd.read_csv('D:\ElectricityTheft\Dataset\data.csv')

## print shape of dataset with rows and columns
print(dataset.shape)
# Out:
# (42372, 1036)

# %%
dataset.head(5)
# Out:
#                             CONS_NO  FLAG  2014/1/1  2014/1/10  2014/1/11  \
# 0  0387DD8A07E07FDA6271170F86AD9151     1       NaN        NaN        NaN
# 1  01D6177B5D4FFE0CABA9EF17DAFC2B84     1       NaN        NaN        NaN
# 2  4B75AC4F2D8434CFF62DB64D0BB43103     1       NaN        NaN        NaN
# 3  B32AC8CC6D5D805AC053557AB05F5343     1       NaN        NaN        NaN
# 4  EDFC78B07BA2908B3395C4EB2304665E     1       2.9       3.42       3.81
#
#    2014/1/12  2014/1/13  2014/1/14  2014/1/15  2014/1/16  2014/1/17  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4       4.58       3.56       4.25       3.86       3.53       3.41
#
#    2014/1/18  2014/1/19  2014/1/2  2014/1/20  2014/1/21  2014/1/22  2014/1/23  \
# ...

# %%
## Here we will check the percentage of nan values present in each feature
## 1 -step make the list of features which has missing values
features_with_na=[features for features in dataset.columns if dataset[features].isnull().sum()>1]
## 2- step print the feature name and the percentage of missing values
nn=[]
for feature in features_with_na:
    print(feature, np.round(dataset[feature].isnull().mean(), 4),  '% missing values')
    nn.append([feature,np.round(dataset[feature].isnull().mean(), 4)])
# Out:
# 2014/1/1 0.3895 % missing values
# 2014/1/10 0.3885 % missing values
# 2014/1/11 0.3885 % missing values
# 2014/1/12 0.3885 % missing values
# 2014/1/13 0.3885 % missing values
# 2014/1/14 0.3885 % missing values
# 2014/1/15 0.3884 % missing values
# 2014/1/16 0.3882 % missing values
# 2014/1/17 0.3882 % missing values
# 2014/1/18 0.3882 % missing values
# 2014/1/19 0.3882 % missing values
# 2014/1/2 0.3894 % missing values
# 2014/1/20 0.3881 % missing values
# 2014/1/21 0.388 % missing values
# 2014/1/22 0.3879 % missing values
# 2014/1/23 0.3879 % missing values
# 2014/1/24 0.3877 % missing values
# 2014/1/25 0.3877 % missing values
# 2014/1/26 0.3878 % missing values
# 2014/1/27 0.3874 % missing values
# 2014/1/28 0.3873 % missing values
# 2014/1/29 0.3871 % missing values
# 2014/1/3 0.3894 % missing values
# 2014/1/30 0.3821 % missing values
# 2014/1/31 0.3821 % missing values
# 2014/1/4 0.3894 % missing values
# 2014/1/5 0.3894 % missing values
# ...

# %%
nn
# Out:
# [['2014/1/1', 0.3895],
#  ['2014/1/10', 0.3885],
#  ['2014/1/11', 0.3885],
#  ['2014/1/12', 0.3885],
#  ['2014/1/13', 0.3885],
#  ['2014/1/14', 0.3885],
#  ['2014/1/15', 0.3884],
#  ['2014/1/16', 0.3882],
#  ['2014/1/17', 0.3882],
#  ['2014/1/18', 0.3882],
#  ['2014/1/19', 0.3882],
#  ['2014/1/2', 0.3894],
#  ['2014/1/20', 0.3881],
#  ['2014/1/21', 0.388],
#  ['2014/1/22', 0.3879],
#  ['2014/1/23', 0.3879],
#  ['2014/1/24', 0.3877],
#  ['2014/1/25', 0.3877],
#  ['2014/1/26', 0.3878],
#  ['2014/1/27', 0.3874],
#  ['2014/1/28', 0.3873],
#  ['2014/1/29', 0.3871],
#  ['2014/1/3', 0.3894],
#  ['2014/1/30', 0.3821],
#  ['2014/1/31', 0.3821],
#  ['2014/1/4', 0.3894],
#  ['2014/1/5', 0.3894],
#  ['2014/1/6', 0.3893],
#  ['2014/1/7', 0.3892],
#  ['2014/1/8', 0.3886],
#  ['2014/1/9', 0.3886],
#  ['2014/10/1', 0.2948],
#  ['2014/10/10', 0.2836],
#  ['2014/10/11', 0.2871],
#  ['2014/10/12', 0.2873],
#  ['2014/10/13', 0.3387],
#  ['2014/10/14', 0.281],
#  ['2014/10/15', 0.2885],
# ...

# %%
dfNval = pd.DataFrame (nn, columns = ['Features', 'Missing Values'])
dfNval.to_csv('D:\ElectricityTheft\missingValues.csv', index=False)

# %%
df_filled = dataset.fillna(dataset.mean())
    #print(feature, np.round(dataset[feature].isnull().mean(), 4),  '% missing values')

# %%
df_filled
# Out:
#                                 CONS_NO  FLAG   2014/1/1  2014/1/10  \
# 0      0387DD8A07E07FDA6271170F86AD9151     1   7.168735   6.954202
# 1      01D6177B5D4FFE0CABA9EF17DAFC2B84     1   7.168735   6.954202
# 2      4B75AC4F2D8434CFF62DB64D0BB43103     1   7.168735   6.954202
# 3      B32AC8CC6D5D805AC053557AB05F5343     1   7.168735   6.954202
# 4      EDFC78B07BA2908B3395C4EB2304665E     1   2.900000   3.420000
# ...                                 ...   ...        ...        ...
# 42367  F1472871E1AFF49D4289564B6377D76C     0   7.168735   6.954202
# 42368  F3C8BBCD2DC26C1E0249DEEF6A4256B7     0   2.700000   4.390000
# 42369  A9A0FE83467A680FBFB0DBFC910DF227     0   0.580000   0.840000
# 42370  D9A6ADA018FA46A55D5438370456AA45     0  16.890000  13.840000
# 42371  F3406636BAD1E6E0826E8EDDC9A1BF00     0   7.168735   6.954202
#
#        2014/1/11  2014/1/12  2014/1/13  2014/1/14  2014/1/15  2014/1/16  \
# 0       6.784099     7.0843   10.51647   7.219633   7.341512   7.160004
# ...

# %%
df_filled.to_csv('D:\ElectricityTheft\dataset\TunedElectricityDataset.csv', index=False)
